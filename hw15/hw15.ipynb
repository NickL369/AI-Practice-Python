# %%
import pandas as pd
import re
from pathlib import Path

from sklearn.model_selection import train_test_split

# %%
csv_path_candidates = [
    "IMDB Dataset.csv",
    "imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv",
    "data/IMDB Dataset.csv",
    "dataset/IMDB Dataset.csv",
    "imdb/IMDB Dataset.csv",
]

csv_path = None
for p in csv_path_candidates:
    if Path(p).exists():
        csv_path = p
        break
# Out:
# Rows: 50000
# Train: 40000 Test: 10000
# Accuracy: 0.9133
# Confusion matrix:
#  [[4538  462]
#  [ 405 4595]]
#               precision    recall  f1-score   support
#
#     negative       0.92      0.91      0.91      5000
#     positive       0.91      0.92      0.91      5000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
#
# Sample predictions: [1 0]
# Sample probabilities: [[0.00672393 0.99327607]
#  [0.99799092 0.00200908]]
