# %%
import os
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# %%
candidates = [
    "IMDB Dataset.csv",
    "imdb/IMDB Dataset.csv",
    "data/IMDB Dataset.csv",
    "hw11/data/IMDB Dataset.csv",
    "kaggle/IMDB Dataset.csv",
]

path = next((p for p in candidates if os.path.exists(p)), None)
if path is None:
    raise FileNotFoundError("IMDB Dataset.csv not found")

df = pd.read_csv(path)

text_col = "review" if "review" in df.columns else df.columns[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       9 path = next((p for p in candidates if os.path.exists(p)), None)
#      10 if path is None:
# ---> 11     raise FileNotFoundError("IMDB Dataset.csv not found")
#      13 df = pd.read_csv(path)
#      15 text_col = "review" if "review" in df.columns else df.columns[0]
#
# FileNotFoundError: IMDB Dataset.csv not found
